# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/prakhar/Projects/Resume-Screening-Engine/data/job_descriptions/JobsDatasetProcessed.csv")

# %%
df.sample(3)
# Out:
#         ID                     Query  \
# 752    780              Data Analyst
# 2216  7297  IT Systems Administrator
# 1150  5189      Data Quality Manager
#
#                                           Job Title  \
# 752              Grievance and Appeals Data Analyst
# 2216                          Systems Administrator
# 1150  Program Manager - School Counseling - 1.0 FTE
#
#                                             Description  \
# 752   FLSA Status: Exempt Department: Grievance and ...
# 2216  About the Position The System Administrator (S...
# 1150  This position is open until filled with the fi...
#
#                                               IT Skills  \
# 752   ****, SQL, Data analysis, Report development/g...
# 2216  Active Directory management, VMware Horizon Vi...
# 1150  Program management, Curriculum development, Tr...
#
#                                             Soft Skills  \
# 752   ****, Analytical thinking, Adaptability, Time ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           3000 non-null   int64
#  1   Query        3000 non-null   object
#  2   Job Title    3000 non-null   object
#  3   Description  3000 non-null   object
#  4   IT Skills    2990 non-null   object
#  5   Soft Skills  2978 non-null   object
#  6   Education    1563 non-null   object
#  7   Experience   1572 non-null   object
#  8   Token Usage  3000 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 211.1+ KB
